# %% [markdown]
# # Consumo de API con la Librería Request - Python

# %% [markdown]
# ¿Qué es una API?
# Una API, o interfaz de programación de aplicaciones, es un servidor que puede utilizar para recuperar y enviar datos mediante código. Las API se utilizan con mayor frecuencia para recuperar datos y ese será el tema central de este tutorial.

# %% [markdown]
# <img src="https://www.dataquest.io/wp-content/uploads/2019/09/api-request.svg"/>

# %%
import requests
import json

import pandas as pd

# %% [markdown]
# Realizaremos nuestra primera solicitud

# %%
response = requests.get('https://api.github.com/user')
print(type(response))
response
# Out:
# <class 'requests.models.Response'>
# <Response [401]>

# %%
# Viendo el codigo de status
response.status_code
# Out:
# 401

# %% [markdown]
# ## Documentacion de los estados de Codigo
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Status

# %%
if response:
    print('Success!')
else:
    print('An error has occurred.')
# Out:
# An error has occurred.

# %% [markdown]
# ## API Correcta

# %%
# Consultando a una API
requests.get('https://api.github.com')
# Out:
# <Response [200]>

# %%
# Consultando el status del codigo
response = requests.get('https://api.github.com')
response.status_code
# Out:
# 200

# %%
if response:
    print('Success!')
else:
    print('An error has occurred.')
# Out:
# Success!

# %% [markdown]
# ## Estructura de un json
# https://www.researchgate.net/publication/305311329/figure/fig3/AS:383788254285830@1468513658266/Figura-3-Ejemplo-de-la-estructura-de-documento-en-formato-JSON-Fuente-autor.png

# %%
# Realizando la peticion
response = requests.get(url = 'https://www.datos.gov.co/resource/7cci-nqqb.json')
print(response.status_code)
response.text
# Out:
# 200
# '[{"orden":"1","fecha":"01/01/2012","a_o":"2012","mes":"01. Enero","d_a":"07. Domingo","gravedad":"Con heridos","peaton":"0","automovil":"1","campero":"0","camioneta":"0","micro":"0","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"0","bicicleta":"0","otro":"0","barrio":"Mutis","hora":"12:15:00","entidad":"AGENTES DTB","nombrecomuna":"17. MUTIS","propietario_de_veh_culo":"Particular","diurnio_nocturno":"Diurno"}\n,{"orden":"2","fecha":"01/01/2012","a_o":"2012","mes":"01. Enero","d_a":"07. Domingo","gravedad":"Solo daños","peaton":"0","automovil":"1","campero":"0","camioneta":"1","micro":"0","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"0","bicicleta":"0","otro":"0","barrio":"Regaderos Norte","hora":"14:00:00","entidad":"AGENTES DTB","nombrecomuna":"02. NORORIENTAL","propietario_de_veh_culo":"Empresa","diurnio_nocturno":"Diurno"}\n,{"orden":"3","fecha":"01/01/2012","a_o":"2012","mes":"01. Enero","d_a":"07. Domingo","gravedad":"Solo daños","peaton":"0","automovil":"0","campero":"0","camioneta":"1","micro":"0","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"0","bicicleta":"0","otro":"0","barrio":"Cabecera Del Llano","hora":"12:00:00","entidad":"AGENTES DTB","nombrecomuna":"12. CABECERA DEL LLANO","propietario_de_veh_culo":"Particular","diurnio_nocturno":"Diurno"}\n,{"orden":"4","fecha":"01/01/2012","a_o":"2012","mes":"01. Enero","d_a":"07. Domingo","gravedad":"Solo daños","peaton":"0","automovil":"1","campero":"0","camioneta":"1","micro":"0","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"0","bicicleta":"0","otro":"0","barrio":"Norte Bajo","hora":"18:30:00","entidad":"AGENTES DTB","nombrecomuna":"03. SAN FRANCISCO","propietario_de_veh_culo":"Empresa","diurnio_nocturno":"Nocturno"}\n,{"orden":"5","fecha":"01/01/2012","a_o":"2012","mes":"01. Enero","d_a":"07. Domingo","gravedad":"Con heridos","peaton":"1","automovil":"0","campero":"0","camioneta":"0","micro":"0","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"1","bicicleta":"0","otro":"0","barrio":"Dangond","hora":"00:30:00","entidad":"AGENTES DTB","nombrecomuna":"11. SUR","propietario_de_veh_culo":"Particular","diurnio_nocturno":"Nocturno"}\n,{"orden":"6","fecha":"01/01/2012","a_o":"2012","mes":"01. Enero","d_a":"07. Domingo","gravedad":"Solo daños","peaton":"0","automovil":"1","campero":"0","camioneta":"0","micro":"0","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"1","bicicleta":"0","otro":"0","barrio":"San Miguel","hora":"21:10:00","entidad":"AGENTES DTB","nombrecomuna":"06. LA CONCORDIA","propietario_de_veh_culo":"Empresa","diurnio_nocturno":"Nocturno"}\n,{"orden":"7","fecha":"02/01/2012","a_o":"2012","mes":"01. Enero","d_a":"01. Lunes","gravedad":"Con heridos","peaton":"1","automovil":"0","campero":"0","camioneta":"0","micro":"1","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"0","bicicleta":"0","otro":"0","barrio":"La Pedregosa","hora":"13:50:00","entidad":"AGENTES DTB","nombrecomuna":"09. LA PEDREGOSA","propietario_de_veh_culo":"Empresa","diurnio_nocturno":"Diurno"}\n,{"orden":"8","fecha":"02/01/2012","a_o":"2012","mes":"01. Enero","d_a":"01. Lunes","gravedad":"Solo daños","peaton":"0","automovil":"0","campero":"0","camioneta":"2","micro":"0","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"0","bicicleta":"0","otro":"0","barrio":"Bucaramanga","hora":"19:20:00","entidad":"AGENTES DTB","nombrecomuna":"08. SUR OCCIDENTE","propietario_de_veh_culo":"Particular","diurnio_nocturno":"Nocturno"}\n,{"orden":"9","fecha":"02/01/2012","a_o":"2012","mes":"01. Enero","d_a":"01. Lunes","gravedad":"Solo daños","peaton":"0","automovil":"1","campero":"0","camioneta":"0","micro":"0","buseta":"0","bus":"0","camion":"0","volqueta":"0","moto":"0","bicicleta":"0","otro":"1","barrio":"Regaderos Norte","hora":"12:00:00","entidad":"AGENTES DTB","nombrecomuna":"02. NORORIENTAL","propietario_de_veh_culo":"Empresa","diurnio_nocturno":"Diurno"}\n,{"orden":"10","fecha":"02/01/2012","a_o":"2012","mes":"01. Enero","d_a": ...

# %%
# Nos ayudamos de la libreria Json para convertir en el texto en diccionario
data = json.loads(response.text)
data
# Out:
# [{'orden': '1',
#   'fecha': '01/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Mutis',
#   'hora': '12:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '17. MUTIS',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '2',
#   'fecha': '01/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Regaderos Norte',
#   'hora': '14:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '02. NORORIENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '3',
#   'fecha': '01/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Cabecera Del Llano',
#   'hora': '12:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '4',
#   'fecha': '01/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Norte Bajo',
#   'hora': '18:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '5',
#   'fecha': '01/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Dangond',
#   'hora': '00:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '11. SUR',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '6',
#   'fecha': '01/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Miguel',
#   'hora': '21:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '7',
#   'fecha': '02/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '1',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Pedregosa',
#   'hora': '13:50:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '8',
#   'fecha': '02/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '2',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bucaramanga',
#   'hora': '19:20:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '08. SUR OCCIDENTE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '9',
#   'fecha': '02/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '1',
#   'barrio': 'Regaderos Norte',
#   'hora': '12:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '02. NORORIENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '10',
#   'fecha': '02/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Tejar Norte',
#   'hora': '16:35:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '01. NORTE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '11',
#   'fecha': '02/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Sotomayor',
#   'hora': '18:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '12',
#   'fecha': '02/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '1',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Norte Bajo',
#   'hora': '08:20:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '13',
#   'fecha': '02/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Fontana',
#   'hora': '13:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '10. PROVENZA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '14',
#   'fecha': '03/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Provenza',
#   'hora': '17:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '10. PROVENZA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '15',
#   'fecha': '03/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '1',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Nuevo Sotomayor',
#   'hora': '06:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '16',
#   'fecha': '03/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '1',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '1',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Cafe Madrid',
#   'hora': '22:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '01. NORTE',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '17',
#   'fecha': '03/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '18:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '18',
#   'fecha': '03/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '18:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '19',
#   'fecha': '03/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '16:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '20',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Alvarez',
#   'hora': '18:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '21',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '3',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Asturias',
#   'hora': '19:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '22',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bolarqui',
#   'hora': '12:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '23',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Los Pinos',
#   'hora': '13:50:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '24',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Manuela Beltran',
#   'hora': '11:22:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '11. SUR',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '25',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '2',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Pedregosa',
#   'hora': '20:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '26',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'NO DISPONIBLE',
#   'hora': '20:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': 'NO DISPONIBLE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '27',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '1',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Alarcon',
#   'hora': '15:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '28',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Real De Minas',
#   'hora': '18:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '07. LA CIUDADELA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '29',
#   'fecha': '04/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Real De Minas',
#   'hora': '18:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '07. LA CIUDADELA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '30',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '1',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Antonia Santos Centro',
#   'hora': '13:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '31',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '1',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '17:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '32',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Conucos',
#   'hora': '19:50:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '33',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '2',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Alarcon',
#   'hora': '09:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '34',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '2',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Nuevo Sotomayor',
#   'hora': '09:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '35',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Alarcon',
#   'hora': '09:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '36',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '1',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'NO DISPONIBLE',
#   'hora': '09:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': 'NO DISPONIBLE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '37',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Antonia Santos Centro',
#   'hora': '10:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '38',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Asturias',
#   'hora': '07:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '39',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Aurora',
#   'hora': '09:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '40',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Mejoras Publicas',
#   'hora': '10:20:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '41',
#   'fecha': '05/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '04. Jueves',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Cabecera Del Llano',
#   'hora': '16:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '42',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Girardot',
#   'hora': '10:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '04. OCCIDENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '43',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '1',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'NO DISPONIBLE',
#   'hora': '16:05:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': 'NO DISPONIBLE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '44',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Real De Minas',
#   'hora': '15:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '07. LA CIUDADELA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '45',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Alonso',
#   'hora': '15:20:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '46',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '1',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Mejoras Publicas',
#   'hora': '20:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '47',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bolarqui',
#   'hora': '11:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '48',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Juan Xxiii',
#   'hora': '05:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '08. SUR OCCIDENTE',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '49',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '1',
#   'otro': '0',
#   'barrio': 'La Ceiba',
#   'hora': '09:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '50',
#   'fecha': '06/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '19:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '51',
#   'fecha': '07/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '17:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '52',
#   'fecha': '07/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '1',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Comuneros',
#   'hora': '18:55:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '53',
#   'fecha': '07/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Pedregosa',
#   'hora': '09:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '54',
#   'fecha': '07/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Cabecera Del Llano',
#   'hora': '18:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '55',
#   'fecha': '07/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Antonia Santos Sur',
#   'hora': '09:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '56',
#   'fecha': '07/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '1',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Cabecera Del Llano',
#   'hora': '11:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '57',
#   'fecha': '07/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Concordia',
#   'hora': '22:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '58',
#   'fecha': '07/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Concordia',
#   'hora': '14:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '59',
#   'fecha': '08/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '1',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Cafe Madrid',
#   'hora': '10:11:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '01. NORTE',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '60',
#   'fecha': '08/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'NO DISPONIBLE',
#   'hora': '16:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': 'NO DISPONIBLE',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '61',
#   'fecha': '08/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Alonso',
#   'hora': '01:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '62',
#   'fecha': '08/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Pedregosa',
#   'hora': '10:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '63',
#   'fecha': '08/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bucaramanga',
#   'hora': '10:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '08. SUR OCCIDENTE',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '64',
#   'fecha': '08/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Con muertos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Asopofavi',
#   'hora': '11:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': 'CORREG. 1',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '65',
#   'fecha': '08/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '07. Domingo',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Real De Minas',
#   'hora': '04:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '07. LA CIUDADELA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '66',
#   'fecha': '09/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bolarqui',
#   'hora': '13:50:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '67',
#   'fecha': '09/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Victoria',
#   'hora': '14:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '68',
#   'fecha': '09/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Francisco',
#   'hora': '03:50:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '69',
#   'fecha': '09/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Francisco',
#   'hora': '18:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '70',
#   'fecha': '09/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Lagos del Cacique',
#   'hora': '13:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '16. LAGOS DEL CACIQUE',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '71',
#   'fecha': '09/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'El Jardin',
#   'hora': '17:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '72',
#   'fecha': '09/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '14:05:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '73',
#   'fecha': '09/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '01. Lunes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Colseguros Norte',
#   'hora': '20:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '01. NORTE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '74',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '1',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Colorados',
#   'hora': '09:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '01. NORTE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '75',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Miraflores',
#   'hora': '07:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '14. MORRORICO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '76',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Nuevo Sotomayor',
#   'hora': '10:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '77',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Villa Alicia',
#   'hora': '00:17:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '11. SUR',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '78',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '1',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Provenza',
#   'hora': '10:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '10. PROVENZA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '79',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Mutis',
#   'hora': '14:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '17. MUTIS',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '80',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Alarcon',
#   'hora': '16:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '81',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '1',
#   'otro': '0',
#   'barrio': 'Alarcon',
#   'hora': '03:50:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '82',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '2',
#   'barrio': 'Garcia Rovira',
#   'hora': '16:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '83',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '1',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Candiles',
#   'hora': '18:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '84',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bolivar',
#   'hora': '14:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '85',
#   'fecha': '10/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '02. Martes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '2',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Norte Bajo',
#   'hora': '18:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '86',
#   'fecha': '11/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '3',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Cabecera Del Llano',
#   'hora': '22:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '87',
#   'fecha': '11/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Antonia Santos Sur',
#   'hora': '07:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '88',
#   'fecha': '11/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '1',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Cabecera Del Llano',
#   'hora': '11:20:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '89',
#   'fecha': '11/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Francisco',
#   'hora': '11:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '90',
#   'fecha': '11/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bolarqui',
#   'hora': '15:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '91',
#   'fecha': '11/01/2012',
#   'a_o': '2012',
#   'mes': '01. Enero',
#   'd_a': '03. Miercoles',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '1',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
# ...
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '971',
#   'fecha': '22/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '04. Jueves',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '2',
#   'barrio': 'Cafe Madrid',
#   'hora': '05:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '01. NORTE',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '972',
#   'fecha': '22/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '04. Jueves',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bolarqui',
#   'hora': '12:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '973',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '1',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Quinta Estrella',
#   'hora': '14:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '05. GARCIA ROVIRA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '974',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '2',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '13:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '975',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '1',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '15:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '976',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Kennedy',
#   'hora': '19:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '01. NORTE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '977',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Bucaramanga',
#   'hora': '07:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '08. SUR OCCIDENTE',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '978',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Diamante I',
#   'hora': '18:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '979',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Lagos del Cacique',
#   'hora': '15:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '16. LAGOS DEL CACIQUE',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '980',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Pedregosa',
#   'hora': '17:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '09. LA PEDREGOSA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '981',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '2',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Mutualidad',
#   'hora': '22:35:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '982',
#   'fecha': '23/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '05. Viernes',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Alonso',
#   'hora': '14:15:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '983',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Regaderos Norte',
#   'hora': '00:50:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '02. NORORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '984',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Real De Minas',
#   'hora': '22:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '07. LA CIUDADELA',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '985',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '2',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Miguel',
#   'hora': '22:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '986',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Ceiba',
#   'hora': '12:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '987',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Concordia',
#   'hora': '13:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '988',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Comuneros',
#   'hora': '14:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '989',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '2',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Albania',
#   'hora': '13:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '14. MORRORICO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '990',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '1',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '1',
#   'barrio': 'San Alonso',
#   'hora': '17:30:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '991',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '1',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Olas Ii',
#   'hora': '09:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '02. NORORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '992',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Mutis',
#   'hora': '08:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '17. MUTIS',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '993',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '2',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Miguel',
#   'hora': '21:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '994',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '1',
#   'otro': '0',
#   'barrio': 'Universidad',
#   'hora': '01:10:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '995',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '2',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Rio de Oro I',
#   'hora': '20:55:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '04. OCCIDENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '996',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '1',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Sotomayor',
#   'hora': '08:40:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '12. CABECERA DEL LLANO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '997',
#   'fecha': '24/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '06. Sabado',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '1',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'La Victoria',
#   'hora': '12:45:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '06. LA CONCORDIA',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '998',
#   'fecha': '25/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '07. Domingo',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'Centro',
#   'hora': '00:28:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '15. CENTRO',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Nocturno'},
#  {'orden': '999',
#   'fecha': '25/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '07. Domingo',
#   'gravedad': 'Con heridos',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '1',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '0',
#   'bus': '0',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '1',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'El Prado',
#   'hora': '08:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '13. ORIENTAL',
#   'propietario_de_veh_culo': 'Particular',
#   'diurnio_nocturno': 'Diurno'},
#  {'orden': '1000',
#   'fecha': '25/03/2012',
#   'a_o': '2012',
#   'mes': '03. Marzo',
#   'd_a': '07. Domingo',
#   'gravedad': 'Solo daños',
#   'peaton': '0',
#   'automovil': '0',
#   'campero': '0',
#   'camioneta': '0',
#   'micro': '0',
#   'buseta': '1',
#   'bus': '1',
#   'camion': '0',
#   'volqueta': '0',
#   'moto': '0',
#   'bicicleta': '0',
#   'otro': '0',
#   'barrio': 'San Francisco',
#   'hora': '11:00:00',
#   'entidad': 'AGENTES DTB',
#   'nombrecomuna': '03. SAN FRANCISCO',
#   'propietario_de_veh_culo': 'Empresa',
#   'diurnio_nocturno': 'Diurno'}]

# %%
# Se genero una lista de Diccionarios
print(type(data))
# Calculamos la cantidad de elementos
print(len(data))
# Out:
# <class 'list'>
# 1000

# %%
# Cada elemento es un diccionario
i = 85 # Elemento
print(type(data[i]))
# Mostramos el elemento
print(data[i])
# Out:
# <class 'dict'>
# {'orden': '86', 'fecha': '11/01/2012', 'a_o': '2012', 'mes': '01. Enero', 'd_a': '03. Miercoles', 'gravedad': 'Solo daños', 'peaton': '0', 'automovil': '3', 'campero': '0', 'camioneta': '0', 'micro': '0', 'buseta': '0', 'bus': '0', 'camion': '0', 'volqueta': '0', 'moto': '0', 'bicicleta': '0', 'otro': '0', 'barrio': 'Cabecera Del Llano', 'hora': '22:30:00', 'entidad': 'AGENTES DTB', 'nombrecomuna': '12. CABECERA DEL LLANO', 'propietario_de_veh_culo': 'Empresa', 'diurnio_nocturno': 'Nocturno'}

# %%
# Convirtiendo nuestra data en dataframe
df = pd.DataFrame(data)
df
# Out:
#     orden       fecha   a_o        mes          d_a     gravedad peaton  \
# 0       1  01/01/2012  2012  01. Enero  07. Domingo  Con heridos      0
# 1       2  01/01/2012  2012  01. Enero  07. Domingo   Solo daños      0
# 2       3  01/01/2012  2012  01. Enero  07. Domingo   Solo daños      0
# 3       4  01/01/2012  2012  01. Enero  07. Domingo   Solo daños      0
# 4       5  01/01/2012  2012  01. Enero  07. Domingo  Con heridos      1
# ..    ...         ...   ...        ...          ...          ...    ...
# 995   996  24/03/2012  2012  03. Marzo   06. Sabado   Solo daños      0
# 996   997  24/03/2012  2012  03. Marzo   06. Sabado  Con heridos      0
# 997   998  25/03/2012  2012  03. Marzo  07. Domingo  Con heridos      0
# 998   999  25/03/2012  2012  03. Marzo  07. Domingo  Con heridos      0
# 999  1000  25/03/2012  2012  03. Marzo  07. Domingo   Solo daños      0
#
#     automovil campero camioneta  ... volqueta moto bicicleta otro  \
# 0           1       0         0  ...        0    0         0    0
# 1           1       0         1  ...        0    0         0    0
# 2           0       0         1  ...        0    0         0    0
# 3           1       0         1  ...        0    0         0    0
# 4           0       0         0  ...        0    1         0    0
# ..        ...     ...       ...  ...      ...  ...       ...  ...
# 995         1       1         0  ...        0    0         0    0
# 996         1       0         0  ...        0    1         0    0
# 997         0       0         0  ...        0    1         0    0
# 998         0       1         0  ...        0    1         0    0
# 999         0       0         0  ...        0    0         0    0
#
#                  barrio      hora      entidad            nombrecomuna  \
# 0                 Mutis  12:15:00  AGENTES DTB               17. MUTIS
# 1       Regaderos Norte  14:00:00  AGENTES DTB         02. NORORIENTAL
# 2    Cabecera Del Llano  12:00:00  AGENTES DTB  12. CABECERA DEL LLANO
# 3            Norte Bajo  18:30:00  AGENTES DTB       03. SAN FRANCISCO
# 4               Dangond  00:30:00  AGENTES DTB                 11. SUR
# ..                  ...       ...          ...                     ...
# 995           Sotomayor  08:40:00  AGENTES DTB  12. CABECERA DEL LLANO
# 996         La Victoria  12:45:00  AGENTES DTB        06. LA CONCORDIA
# 997              Centro  00:28:00  AGENTES DTB              15. CENTRO
# 998            El Prado  08:00:00  AGENTES DTB            13. ORIENTAL
# 999       San Francisco  11:00:00  AGENTES DTB       03. SAN FRANCISCO
#
#     propietario_de_veh_culo diurnio_nocturno
# 0                Particular           Diurno
# 1                   Empresa           Diurno
# 2                Particular           Diurno
# 3                   Empresa         Nocturno
# 4                Particular         Nocturno
# ..                      ...              ...
# 995                 Empresa           Diurno
# 996              Particular           Diurno
# 997              Particular         Nocturno
# 998              Particular           Diurno
# 999                 Empresa           Diurno
#
# [1000 rows x 24 columns]

# %% [markdown]
# ## Cuando la data no devuelve una lista de diccionarios

# %%
# Hacemos la peticion
response = requests.get(url = 'https://api.github.com')
# Generamos la data
if response.status_code == 200:
    print('Success!')
    # Pasamos el texto a diccionarios
    data = json.loads(response.text)
    print(data)
    # Pasamos la data a Dataframe
    df = pd.DataFrame(data)
    display(df)
else:
    print('An error has occurred.')
# Out:
# Success!
# {'current_user_url': 'https://api.github.com/user', 'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}', 'authorizations_url': 'https://api.github.com/authorizations', 'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}', 'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}', 'emails_url': 'https://api.github.com/user/emails', 'emojis_url': 'https://api.github.com/emojis', 'events_url': 'https://api.github.com/events', 'feeds_url': 'https://api.github.com/feeds', 'followers_url': 'https://api.github.com/user/followers', 'following_url': 'https://api.github.com/user/following{/target}', 'gists_url': 'https://api.github.com/gists{/gist_id}', 'hub_url': 'https://api.github.com/hub', 'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}', 'issues_url': 'https://api.github.com/issues', 'keys_url': 'https://api.github.com/user/keys', 'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}', 'notifications_url': 'https://api.github.com/notifications', 'organization_url': 'https://api.github.com/orgs/{org}', 'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}', 'organization_teams_url': 'https://api.github.com/orgs/{org}/teams', 'public_gists_url': 'https://api.github.com/gists/public', 'rate_limit_url': 'https://api.github.com/rate_limit', 'repository_url': 'https://api.github.com/repos/{owner}/{repo}', 'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}', 'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}', 'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}', 'starred_gists_url': 'https://api.github.com/gists/starred', 'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}', 'user_url': 'https://api.github.com/users/{user}', 'user_organizations_url': 'https://api.github.com/user/orgs', 'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}', 'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 10
#       8     print(data)
#       9     # Pasamos la data a Dataframe
# ---> 10     df = pd.DataFrame(data)
#      11     display(df)
#      12 else:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:645, in _extract_index(data)
#     642         raise ValueError("Per-column arrays must each be 1-dimensional")
#     644 if not indexes and not raw_lengths:
# --> 645     raise ValueError("If using all scalar values, you must pass an index")
#     647 if have_series:
#     648     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
# Para solucionar este problema creamos una lista con el diccionario devuelto
print('*' * 20 + ' Data Original ' + '*' * 20)
print(data)
print(type(data))
print('*' * 20 + ' Data En Lista ' + '*' * 20)
# Pasando la data a una lista
data = [data]
print(data)
print(type(data))
# Out:
# ******************** Data Original ********************
# {'current_user_url': 'https://api.github.com/user', 'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}', 'authorizations_url': 'https://api.github.com/authorizations', 'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}', 'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}', 'emails_url': 'https://api.github.com/user/emails', 'emojis_url': 'https://api.github.com/emojis', 'events_url': 'https://api.github.com/events', 'feeds_url': 'https://api.github.com/feeds', 'followers_url': 'https://api.github.com/user/followers', 'following_url': 'https://api.github.com/user/following{/target}', 'gists_url': 'https://api.github.com/gists{/gist_id}', 'hub_url': 'https://api.github.com/hub', 'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}', 'issues_url': 'https://api.github.com/issues', 'keys_url': 'https://api.github.com/user/keys', 'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}', 'notifications_url': 'https://api.github.com/notifications', 'organization_url': 'https://api.github.com/orgs/{org}', 'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}', 'organization_teams_url': 'https://api.github.com/orgs/{org}/teams', 'public_gists_url': 'https://api.github.com/gists/public', 'rate_limit_url': 'https://api.github.com/rate_limit', 'repository_url': 'https://api.github.com/repos/{owner}/{repo}', 'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}', 'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}', 'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}', 'starred_gists_url': 'https://api.github.com/gists/starred', 'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}', 'user_url': 'https://api.github.com/users/{user}', 'user_organizations_url': 'https://api.github.com/user/orgs', 'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}', 'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}
# <class 'dict'>
# ******************** Data En Lista ********************
# [{'current_user_url': 'https://api.github.com/user', 'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}', 'authorizations_url': 'https://api.github.com/authorizations', 'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}', 'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}', 'emails_url': 'https://api.github.com/user/emails', 'emojis_url': 'https://api.github.com/emojis', 'events_url': 'https://api.github.com/events', 'feeds_url': 'https://api.github.com/feeds', 'followers_url': 'https://api.github.com/user/followers', 'following_url': 'https://api.github.com/user/following{/target}', 'gists_url': 'https://api.github.com/gists{/gist_id}', 'hub_url': 'https://api.github.com/hub', 'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}', 'issues_url': 'https://api.github.com/issues', 'keys_url': 'https://api.github.com/user/keys', 'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}', 'notifications_url': 'https://api.github.com/notifications', 'organization_url': 'https://api.github.com/orgs/{org}', 'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}', 'organization_teams_url': 'https://api.github.com/orgs/{org}/teams', 'public_gists_url': 'https://api.github.com/gists/public', 'rate_limit_url': 'https://api.github.com/rate_limit', 'repository_url': 'https://api.github.com/repos/{owner}/{repo}', 'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}', 'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}', 'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}', 'starred_gists_url': 'https://api.github.com/gists/starred', 'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}', 'user_url': 'https://api.github.com/users/{user}', 'user_organizations_url': 'https://api.github.com/user/orgs', 'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}', 'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}]
# <class 'list'>

# %%
# Ahora si podemos pasar la data a Dataframe
df = pd.DataFrame(data).T
df
# Out:
#                                                                                       0
# current_user_url                                            https://api.github.com/user
# current_user_authorizations_html_url  https://github.com/settings/connections/applic...
# authorizations_url                                https://api.github.com/authorizations
# code_search_url                       https://api.github.com/search/code?q={query}{&...
# commit_search_url                     https://api.github.com/search/commits?q={query...
# emails_url                                           https://api.github.com/user/emails
# emojis_url                                                https://api.github.com/emojis
# events_url                                                https://api.github.com/events
# feeds_url                                                  https://api.github.com/feeds
# followers_url                                     https://api.github.com/user/followers
# following_url                            https://api.github.com/user/following{/target}
# gists_url                                        https://api.github.com/gists{/gist_id}
# hub_url                                                      https://api.github.com/hub
# issue_search_url                      https://api.github.com/search/issues?q={query}...
# issues_url                                                https://api.github.com/issues
# keys_url                                               https://api.github.com/user/keys
# label_search_url                      https://api.github.com/search/labels?q={query}...
# notifications_url                                  https://api.github.com/notifications
# organization_url                                      https://api.github.com/orgs/{org}
# organization_repositories_url         https://api.github.com/orgs/{org}/repos{?type,...
# organization_teams_url                          https://api.github.com/orgs/{org}/teams
# public_gists_url                                    https://api.github.com/gists/public
# rate_limit_url                                        https://api.github.com/rate_limit
# repository_url                              https://api.github.com/repos/{owner}/{repo}
# repository_search_url                 https://api.github.com/search/repositories?q={...
# current_user_repositories_url         https://api.github.com/user/repos{?type,page,p...
# starred_url                           https://api.github.com/user/starred{/owner}{/r...
# starred_gists_url                                  https://api.github.com/gists/starred
# topic_search_url                      https://api.github.com/search/topics?q={query}...
# user_url                                            https://api.github.com/users/{user}
# user_organizations_url                                 https://api.github.com/user/orgs
# user_repositories_url                 https://api.github.com/users/{user}/repos{?typ...
# user_search_url                       https://api.github.com/search/users?q={query}{...

# %% [markdown]
# ## Cuando la data esta incluida dentro del json

# %%
# Haciendo la solicitud
response = requests.get(url = 'https://pokeapi.co/api/v2/generation')
response.text
# Out:
# '{"count":9,"next":null,"previous":null,"results":[{"name":"generation-i","url":"https://pokeapi.co/api/v2/generation/1/"},{"name":"generation-ii","url":"https://pokeapi.co/api/v2/generation/2/"},{"name":"generation-iii","url":"https://pokeapi.co/api/v2/generation/3/"},{"name":"generation-iv","url":"https://pokeapi.co/api/v2/generation/4/"},{"name":"generation-v","url":"https://pokeapi.co/api/v2/generation/5/"},{"name":"generation-vi","url":"https://pokeapi.co/api/v2/generation/6/"},{"name":"generation-vii","url":"https://pokeapi.co/api/v2/generation/7/"},{"name":"generation-viii","url":"https://pokeapi.co/api/v2/generation/8/"},{"name":"generation-ix","url":"https://pokeapi.co/api/v2/generation/9/"}]}'

# %%
# Pasando a Diccionarios
data = json.loads(response.text)
data
# Out:
# {'count': 9,
#  'next': None,
#  'previous': None,
#  'results': [{'name': 'generation-i',
#    'url': 'https://pokeapi.co/api/v2/generation/1/'},
#   {'name': 'generation-ii', 'url': 'https://pokeapi.co/api/v2/generation/2/'},
#   {'name': 'generation-iii', 'url': 'https://pokeapi.co/api/v2/generation/3/'},
#   {'name': 'generation-iv', 'url': 'https://pokeapi.co/api/v2/generation/4/'},
#   {'name': 'generation-v', 'url': 'https://pokeapi.co/api/v2/generation/5/'},
#   {'name': 'generation-vi', 'url': 'https://pokeapi.co/api/v2/generation/6/'},
#   {'name': 'generation-vii', 'url': 'https://pokeapi.co/api/v2/generation/7/'},
#   {'name': 'generation-viii',
#    'url': 'https://pokeapi.co/api/v2/generation/8/'},
#   {'name': 'generation-ix', 'url': 'https://pokeapi.co/api/v2/generation/9/'}]}

# %%
df = pd.DataFrame([data])
df
# Out:
#    count  next previous                                            results
# 0      9  None     None  [{'name': 'generation-i', 'url': 'https://poke...

# %%
# Vamos directo a la data
data['results']
# Out:
# [{'name': 'generation-i', 'url': 'https://pokeapi.co/api/v2/generation/1/'},
#  {'name': 'generation-ii', 'url': 'https://pokeapi.co/api/v2/generation/2/'},
#  {'name': 'generation-iii', 'url': 'https://pokeapi.co/api/v2/generation/3/'},
#  {'name': 'generation-iv', 'url': 'https://pokeapi.co/api/v2/generation/4/'},
#  {'name': 'generation-v', 'url': 'https://pokeapi.co/api/v2/generation/5/'},
#  {'name': 'generation-vi', 'url': 'https://pokeapi.co/api/v2/generation/6/'},
#  {'name': 'generation-vii', 'url': 'https://pokeapi.co/api/v2/generation/7/'},
#  {'name': 'generation-viii', 'url': 'https://pokeapi.co/api/v2/generation/8/'},
#  {'name': 'generation-ix', 'url': 'https://pokeapi.co/api/v2/generation/9/'}]

# %%
# Convertimos la data en dataframe
df = pd.DataFrame(data['results'])
df
# Out:
#               name                                      url
# 0     generation-i  https://pokeapi.co/api/v2/generation/1/
# 1    generation-ii  https://pokeapi.co/api/v2/generation/2/
# 2   generation-iii  https://pokeapi.co/api/v2/generation/3/
# 3    generation-iv  https://pokeapi.co/api/v2/generation/4/
# 4     generation-v  https://pokeapi.co/api/v2/generation/5/
# 5    generation-vi  https://pokeapi.co/api/v2/generation/6/
# 6   generation-vii  https://pokeapi.co/api/v2/generation/7/
# 7  generation-viii  https://pokeapi.co/api/v2/generation/8/
# 8    generation-ix  https://pokeapi.co/api/v2/generation/9/

# %% [markdown]
# # Tu turno

# %%
# Haciendo la solicitud
response = requests.get(url = 'https://pokeapi.co/api/v2/type/')
response.text
# Out:
# '{"count":20,"next":null,"previous":null,"results":[{"name":"normal","url":"https://pokeapi.co/api/v2/type/1/"},{"name":"fighting","url":"https://pokeapi.co/api/v2/type/2/"},{"name":"flying","url":"https://pokeapi.co/api/v2/type/3/"},{"name":"poison","url":"https://pokeapi.co/api/v2/type/4/"},{"name":"ground","url":"https://pokeapi.co/api/v2/type/5/"},{"name":"rock","url":"https://pokeapi.co/api/v2/type/6/"},{"name":"bug","url":"https://pokeapi.co/api/v2/type/7/"},{"name":"ghost","url":"https://pokeapi.co/api/v2/type/8/"},{"name":"steel","url":"https://pokeapi.co/api/v2/type/9/"},{"name":"fire","url":"https://pokeapi.co/api/v2/type/10/"},{"name":"water","url":"https://pokeapi.co/api/v2/type/11/"},{"name":"grass","url":"https://pokeapi.co/api/v2/type/12/"},{"name":"electric","url":"https://pokeapi.co/api/v2/type/13/"},{"name":"psychic","url":"https://pokeapi.co/api/v2/type/14/"},{"name":"ice","url":"https://pokeapi.co/api/v2/type/15/"},{"name":"dragon","url":"https://pokeapi.co/api/v2/type/16/"},{"name":"dark","url":"https://pokeapi.co/api/v2/type/17/"},{"name":"fairy","url":"https://pokeapi.co/api/v2/type/18/"},{"name":"unknown","url":"https://pokeapi.co/api/v2/type/10001/"},{"name":"shadow","url":"https://pokeapi.co/api/v2/type/10002/"}]}'

# %%
# Pasar a dataframe los tipos de pokemon
data = json.loads(response.text)
data
# Out:
# {'count': 20,
#  'next': None,
#  'previous': None,
#  'results': [{'name': 'normal', 'url': 'https://pokeapi.co/api/v2/type/1/'},
#   {'name': 'fighting', 'url': 'https://pokeapi.co/api/v2/type/2/'},
#   {'name': 'flying', 'url': 'https://pokeapi.co/api/v2/type/3/'},
#   {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'},
#   {'name': 'ground', 'url': 'https://pokeapi.co/api/v2/type/5/'},
#   {'name': 'rock', 'url': 'https://pokeapi.co/api/v2/type/6/'},
#   {'name': 'bug', 'url': 'https://pokeapi.co/api/v2/type/7/'},
#   {'name': 'ghost', 'url': 'https://pokeapi.co/api/v2/type/8/'},
#   {'name': 'steel', 'url': 'https://pokeapi.co/api/v2/type/9/'},
#   {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'},
#   {'name': 'water', 'url': 'https://pokeapi.co/api/v2/type/11/'},
#   {'name': 'grass', 'url': 'https://pokeapi.co/api/v2/type/12/'},
#   {'name': 'electric', 'url': 'https://pokeapi.co/api/v2/type/13/'},
#   {'name': 'psychic', 'url': 'https://pokeapi.co/api/v2/type/14/'},
#   {'name': 'ice', 'url': 'https://pokeapi.co/api/v2/type/15/'},
#   {'name': 'dragon', 'url': 'https://pokeapi.co/api/v2/type/16/'},
#   {'name': 'dark', 'url': 'https://pokeapi.co/api/v2/type/17/'},
#   {'name': 'fairy', 'url': 'https://pokeapi.co/api/v2/type/18/'},
#   {'name': 'unknown', 'url': 'https://pokeapi.co/api/v2/type/10001/'},
#   {'name': 'shadow', 'url': 'https://pokeapi.co/api/v2/type/10002/'}]}

# %%
pd.DataFrame(data['results'])
# Out:
#         name                                    url
# 0     normal      https://pokeapi.co/api/v2/type/1/
# 1   fighting      https://pokeapi.co/api/v2/type/2/
# 2     flying      https://pokeapi.co/api/v2/type/3/
# 3     poison      https://pokeapi.co/api/v2/type/4/
# 4     ground      https://pokeapi.co/api/v2/type/5/
# 5       rock      https://pokeapi.co/api/v2/type/6/
# 6        bug      https://pokeapi.co/api/v2/type/7/
# 7      ghost      https://pokeapi.co/api/v2/type/8/
# 8      steel      https://pokeapi.co/api/v2/type/9/
# 9       fire     https://pokeapi.co/api/v2/type/10/
# 10     water     https://pokeapi.co/api/v2/type/11/
# 11     grass     https://pokeapi.co/api/v2/type/12/
# 12  electric     https://pokeapi.co/api/v2/type/13/
# 13   psychic     https://pokeapi.co/api/v2/type/14/
# 14       ice     https://pokeapi.co/api/v2/type/15/
# 15    dragon     https://pokeapi.co/api/v2/type/16/
# 16      dark     https://pokeapi.co/api/v2/type/17/
# 17     fairy     https://pokeapi.co/api/v2/type/18/
# 18   unknown  https://pokeapi.co/api/v2/type/10001/
# 19    shadow  https://pokeapi.co/api/v2/type/10002/

# %% [markdown]
# ## Cuando la API no devuelte en una solicitud todos los datos

# %%
# Haciendo la solicitud
response = requests.get(url = 'https://pokeapi.co/api/v2/pokemon/')
response.text
# Out:
# '{"count":1302,"next":"https://pokeapi.co/api/v2/pokemon/?offset=20&limit=20","previous":null,"results":[{"name":"bulbasaur","url":"https://pokeapi.co/api/v2/pokemon/1/"},{"name":"ivysaur","url":"https://pokeapi.co/api/v2/pokemon/2/"},{"name":"venusaur","url":"https://pokeapi.co/api/v2/pokemon/3/"},{"name":"charmander","url":"https://pokeapi.co/api/v2/pokemon/4/"},{"name":"charmeleon","url":"https://pokeapi.co/api/v2/pokemon/5/"},{"name":"charizard","url":"https://pokeapi.co/api/v2/pokemon/6/"},{"name":"squirtle","url":"https://pokeapi.co/api/v2/pokemon/7/"},{"name":"wartortle","url":"https://pokeapi.co/api/v2/pokemon/8/"},{"name":"blastoise","url":"https://pokeapi.co/api/v2/pokemon/9/"},{"name":"caterpie","url":"https://pokeapi.co/api/v2/pokemon/10/"},{"name":"metapod","url":"https://pokeapi.co/api/v2/pokemon/11/"},{"name":"butterfree","url":"https://pokeapi.co/api/v2/pokemon/12/"},{"name":"weedle","url":"https://pokeapi.co/api/v2/pokemon/13/"},{"name":"kakuna","url":"https://pokeapi.co/api/v2/pokemon/14/"},{"name":"beedrill","url":"https://pokeapi.co/api/v2/pokemon/15/"},{"name":"pidgey","url":"https://pokeapi.co/api/v2/pokemon/16/"},{"name":"pidgeotto","url":"https://pokeapi.co/api/v2/pokemon/17/"},{"name":"pidgeot","url":"https://pokeapi.co/api/v2/pokemon/18/"},{"name":"rattata","url":"https://pokeapi.co/api/v2/pokemon/19/"},{"name":"raticate","url":"https://pokeapi.co/api/v2/pokemon/20/"}]}'

# %%
# Pasando a Diccionario
data = json.loads(response.text)
data
# Out:
# {'count': 1302,
#  'next': 'https://pokeapi.co/api/v2/pokemon/?offset=20&limit=20',
#  'previous': None,
#  'results': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#   {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#   {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#   {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#   {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#   {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#   {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#   {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
#   {'name': 'butterfree', 'url': 'https://pokeapi.co/api/v2/pokemon/12/'},
#   {'name': 'weedle', 'url': 'https://pokeapi.co/api/v2/pokemon/13/'},
#   {'name': 'kakuna', 'url': 'https://pokeapi.co/api/v2/pokemon/14/'},
#   {'name': 'beedrill', 'url': 'https://pokeapi.co/api/v2/pokemon/15/'},
#   {'name': 'pidgey', 'url': 'https://pokeapi.co/api/v2/pokemon/16/'},
#   {'name': 'pidgeotto', 'url': 'https://pokeapi.co/api/v2/pokemon/17/'},
#   {'name': 'pidgeot', 'url': 'https://pokeapi.co/api/v2/pokemon/18/'},
#   {'name': 'rattata', 'url': 'https://pokeapi.co/api/v2/pokemon/19/'},
#   {'name': 'raticate', 'url': 'https://pokeapi.co/api/v2/pokemon/20/'}]}

# %%
# Pasando a dataframe
df = pd.DataFrame(data['results'])
df
# Out:
#           name                                    url
# 0    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/
# 1      ivysaur   https://pokeapi.co/api/v2/pokemon/2/
# 2     venusaur   https://pokeapi.co/api/v2/pokemon/3/
# 3   charmander   https://pokeapi.co/api/v2/pokemon/4/
# 4   charmeleon   https://pokeapi.co/api/v2/pokemon/5/
# 5    charizard   https://pokeapi.co/api/v2/pokemon/6/
# 6     squirtle   https://pokeapi.co/api/v2/pokemon/7/
# 7    wartortle   https://pokeapi.co/api/v2/pokemon/8/
# 8    blastoise   https://pokeapi.co/api/v2/pokemon/9/
# 9     caterpie  https://pokeapi.co/api/v2/pokemon/10/
# 10     metapod  https://pokeapi.co/api/v2/pokemon/11/
# 11  butterfree  https://pokeapi.co/api/v2/pokemon/12/
# 12      weedle  https://pokeapi.co/api/v2/pokemon/13/
# 13      kakuna  https://pokeapi.co/api/v2/pokemon/14/
# 14    beedrill  https://pokeapi.co/api/v2/pokemon/15/
# 15      pidgey  https://pokeapi.co/api/v2/pokemon/16/
# 16   pidgeotto  https://pokeapi.co/api/v2/pokemon/17/
# 17     pidgeot  https://pokeapi.co/api/v2/pokemon/18/
# 18     rattata  https://pokeapi.co/api/v2/pokemon/19/
# 19    raticate  https://pokeapi.co/api/v2/pokemon/20/

# %% [markdown]
# ## Parametros

# %%
# Hacemos la solicitud con parametros
qRegistros = data['count']
response = requests.get(url = 'https://pokeapi.co/api/v2/pokemon/',
                        params={'offset': 50, 'limit':5},
)
# Generamos los diccionarios
data = json.loads(response.text)
# Pasando a dataframe
df = pd.DataFrame(data['results'])
df
# Out:
#       name                                    url
# 0  dugtrio  https://pokeapi.co/api/v2/pokemon/51/
# 1   meowth  https://pokeapi.co/api/v2/pokemon/52/
# 2  persian  https://pokeapi.co/api/v2/pokemon/53/
# 3  psyduck  https://pokeapi.co/api/v2/pokemon/54/
# 4  golduck  https://pokeapi.co/api/v2/pokemon/55/

# %% [markdown]
# # Ejercicios

# %%
# Completar la informacion del pokemon

# %%
# Del API https://pokeapi.co/docs/v2 elegir una y convertirla a dataframe
