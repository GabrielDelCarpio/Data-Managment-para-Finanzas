# %% [markdown]
# # Pandas - SQL Manejo Datos

# %%
# Importar pandas para manejo de data estructurada
import numpy as np
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# ## Importacion de los Datos

# %%
# Importando desde csv
df = pd.read_csv('https://raw.githubusercontent.com/aldochavez/datasets/main/Estudiantes.csv', sep = '|')
df.head(5)
# Out:
#    codEstudiante       nombre    apellido   telefono
# 0              1  Jean Pierre      Levano  987654321
# 1              2        Sandy    Carbajal  987654322
# 2              3     Josselin       Taipe  987654323
# 3              4        James  Surichaqui  987654324
# 4              5       Javier        Ruiz  987654325

# %%
# Importando desde csv
dfHipotecario = pd.read_csv('https://raw.githubusercontent.com/aldochavez/datasets/main/AdquisicionCreditoHipotecario.csv')
dfHipotecario.head(5)
# Out:
#     Loan ID Gender Married Dependents     Education Self Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# Importando desde csv
dfpMorosidad = pd.read_csv('https://raw.githubusercontent.com/aldochavez/datasets/main/morosidad.csv')
dfpMorosidad.head(5)
# Out:
#    ID  edad  meses  max_ant   ingreso  score  tipo_vivienda  zona  nivel
# 0   1    28    122        9   1115.09    206              4     1      5
# 1   2    27    173       61   2450.00    205              2     1      5
# 2   3    37    185        4   1390.00    177              2     3      5
# 3   4    34    262       20   2200.00    216              2     1      2
# 4   5    40    150       17  10000.00    185              2     1      2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Resolver la pregunta 1
dfDepositos = pd.read_csv('/content/AdquisicionCreditoHipotecario.csv', sep = ';',skiprows=2)
dfDepositos
# Out:
#                Gender      Married  Cuenta de Loan ID  \
# 0              Female           No                 66
# 1              Female          Yes                 25
# 2              Female  (en blanco)                  1
# 3        Total Female          NaN                 92
# 4                Male           No                 99
# 5                Male          Yes                275
# 6                Male  (en blanco)                  2
# 7          Total Male          NaN                376
# 8         (en blanco)           No                  3
# 9         (en blanco)          Yes                  9
# 10  Total (en blanco)          NaN                 12
# 11      Total general          NaN                480
#
#     Promedio de ApplicantIncome
# 0                   4337.196970
# 1                   5246.920000
# 2                  10047.000000
# 3                   4646.467391
# 4                   5710.777778
# 5                   6106.112727
# ...

# %%
# Resolver la pregunta 2
dfClientes=pd.read_excel("/content/Clientes_2016_2017.xlsx", skiprows=2)
dfClientes
# Out:
#           ID  EDAD         SEXO            REGION  INGRESOS   CASADO  HIJOS  \
# 0    ID12701    23  MASCULINO           LIMA_ESTE     18766   SI          0
# 1    ID12702    30  MASCULINO    LIMA_CENTRO           9915  NO           1
# 2    ID12703    45     FEMENINO  LIMA_CENTRO          21881  NO           0
# 3    ID12704    50  MASCULINO    LIMA_NORTE           46794   SI          2
# 4    ID12705    41     FEMENINO         LIMA_ESTE     20721   SI          0
# ..       ...   ...          ...               ...       ...      ...    ...
# 193  ID12896    66  MASCULINO           LIMA_ESTE     58792  NO           1
# 194  ID12897    19  MASCULINO           LIMA_ESTE     17906  NO           2
# 195  ID12898    54  MASCULINO    LIMA_CENTRO          29348  NO           0
# 196  ID12899    42     FEMENINO  LIMA_NORTE           20552   SI          0
# 197  ID12900    34  MASCULINO           LIMA_ESTE     25843  NO           2
#
#     AUTO
# 0     SI
# 1    NO
# 2     SI
# 3    NO
# ...

# %% [markdown]
# ### Select

# %%
# Forma 1

# SELECT meses, score, zona
# FROM dfsMorosidad

dfpMorosidad[['meses', 'score', 'zona']]
# Out:
#      meses  score  zona
# 0      122    206     1
# 1      173    205     1
# 2      185    177     3
# 3      262    216     1
# 4      150    185     1
# ..     ...    ...   ...
# 295    144    156     3
# 296    131    156     1
# 297    130    188     1
# 298    170    219     1
# 299    152    164     1
#
# [300 rows x 3 columns]

# %%
# Forma 2
dfpMorosidad.loc[: , ['meses', 'score', 'zona']]
# Out:
#      meses  score  zona
# 0      122    206     1
# 1      173    205     1
# 2      185    177     3
# 3      262    216     1
# 4      150    185     1
# ..     ...    ...   ...
# 295    144    156     3
# 296    131    156     1
# 297    130    188     1
# 298    170    219     1
# 299    152    164     1
#
# [300 rows x 3 columns]

# %%
# Forma 3
columnas = ['meses','score']
dfpMorosidad[columnas]
# Out:
#      meses  score
# 0      122    206
# 1      173    205
# 2      185    177
# 3      262    216
# 4      150    185
# ..     ...    ...
# 295    144    156
# 296    131    156
# 297    130    188
# 298    170    219
# 299    152    164
#
# [300 rows x 2 columns]

# %%
# Resolver la pregunta 3
columnas = ['ID', 'SEXO', 'INGRESOS']
dfClientes[columnas]
# Out:
#           ID         SEXO  INGRESOS
# 0    ID12701  MASCULINO       18766
# 1    ID12702  MASCULINO        9915
# 2    ID12703     FEMENINO     21881
# 3    ID12704  MASCULINO       46794
# 4    ID12705     FEMENINO     20721
# ..       ...          ...       ...
# 193  ID12896  MASCULINO       58792
# 194  ID12897  MASCULINO       17906
# 195  ID12898  MASCULINO       29348
# 196  ID12899     FEMENINO     20552
# 197  ID12900  MASCULINO       25843
#
# [198 rows x 3 columns]

# %%
dfClientes.loc[:, ['ID','SEXO','INGRESOS']]
# Out:
#           ID         SEXO  INGRESOS
# 0    ID12701  MASCULINO       18766
# 1    ID12702  MASCULINO        9915
# 2    ID12703     FEMENINO     21881
# 3    ID12704  MASCULINO       46794
# 4    ID12705     FEMENINO     20721
# ..       ...          ...       ...
# 193  ID12896  MASCULINO       58792
# 194  ID12897  MASCULINO       17906
# 195  ID12898  MASCULINO       29348
# 196  ID12899     FEMENINO     20552
# 197  ID12900  MASCULINO       25843
#
# [198 rows x 3 columns]

# %%
# Resolver la pregunta 4
dfClientes.loc[:,'EDAD':'HIJOS']
# Out:
#      EDAD         SEXO            REGION  INGRESOS   CASADO  HIJOS
# 0      23  MASCULINO           LIMA_ESTE     18766   SI          0
# 1      30  MASCULINO    LIMA_CENTRO           9915  NO           1
# 2      45     FEMENINO  LIMA_CENTRO          21881  NO           0
# 3      50  MASCULINO    LIMA_NORTE           46794   SI          2
# 4      41     FEMENINO         LIMA_ESTE     20721   SI          0
# ..    ...          ...               ...       ...      ...    ...
# 193    66  MASCULINO           LIMA_ESTE     58792  NO           1
# 194    19  MASCULINO           LIMA_ESTE     17906  NO           2
# 195    54  MASCULINO    LIMA_CENTRO          29348  NO           0
# 196    42     FEMENINO  LIMA_NORTE           20552   SI          0
# 197    34  MASCULINO           LIMA_ESTE     25843  NO           2
#
# [198 rows x 6 columns]

# %%
dfClientes.iloc[:, 1:-1]
# Out:
#      EDAD         SEXO            REGION  INGRESOS   CASADO  HIJOS
# 0      23  MASCULINO           LIMA_ESTE     18766   SI          0
# 1      30  MASCULINO    LIMA_CENTRO           9915  NO           1
# 2      45     FEMENINO  LIMA_CENTRO          21881  NO           0
# 3      50  MASCULINO    LIMA_NORTE           46794   SI          2
# 4      41     FEMENINO         LIMA_ESTE     20721   SI          0
# ..    ...          ...               ...       ...      ...    ...
# 193    66  MASCULINO           LIMA_ESTE     58792  NO           1
# 194    19  MASCULINO           LIMA_ESTE     17906  NO           2
# 195    54  MASCULINO    LIMA_CENTRO          29348  NO           0
# 196    42     FEMENINO  LIMA_NORTE           20552   SI          0
# 197    34  MASCULINO           LIMA_ESTE     25843  NO           2
#
# [198 rows x 6 columns]

# %% [markdown]
# ### Where

# %%
# Forma 1

# SELECT *
# FROM dfpMorosidad
# WHERE ID = 10

dfpMorosidad.loc[dfpMorosidad['ID'] == 10]
# Out:
#    ID  edad  meses  max_ant  ingreso  score  tipo_vivienda  zona  nivel
# 9  10    36    216        0   4000.0    175              2     4      2

# %%
# Forma 1

# SELECT ID, meses, score
# FROM dfpMorosidad
# WHERE ID = 10

listCol = ['ID', 'meses', 'score']
filtro_ID = ( dfpMorosidad['ID'] == 10 )
dfpMorosidad.loc[ filtro_ID , listCol]
# Out:
#    ID  meses  score
# 9  10    216    175

# %% [markdown]
# **Ejemplo 1:
# Genere una consulta que liste los clientes cuya edad sea mayor a 25**

# %%
# Resolver Aqui
filtro_edad = ( dfpMorosidad['edad'] > 25 )
dfpMorosidad.loc[ filtro_edad ]
# Out:
#       ID  edad  meses  max_ant   ingreso  score  tipo_vivienda  zona  nivel
# 0      1    28    122        9   1115.09    206              4     1      5
# 1      2    27    173       61   2450.00    205              2     1      5
# 2      3    37    185        4   1390.00    177              2     3      5
# 3      4    34    262       20   2200.00    216              2     1      2
# 4      5    40    150       17  10000.00    185              2     1      2
# ..   ...   ...    ...      ...       ...    ...            ...   ...    ...
# 292  293    39    125        0    880.00    215              4     1      5
# 293  294    35    288        0   4100.00    192              2     3      1
# 294  295    30    145        8   1500.00    194              2     1      5
# 297  298    31    130       12   2000.00    188              2     1      2
# 298  299    33    170       12   5600.00    219              4     1      2
#
# [246 rows x 9 columns]

# %%
# Varios valores - Forma 1

# SELECT *
# FROM dfpMorosidad
# WHERE ID in (1, 10, 30)

listaID = [1, 10, 30]
dfpMorosidad.loc[dfpMorosidad['ID'].isin(listaID)]
# Out:
#     ID  edad  meses  max_ant  ingreso  score  tipo_vivienda  zona  nivel
# 0    1    28    122        9  1115.09    206              4     1      5
# 9   10    36    216        0  4000.00    175              2     4      2
# 29  30    33    152        0  2030.99    177              2     1      5

# %% [markdown]
# **OJO**: Para negar podemos usar el operador **~**

# %%
# Negacion
listaID = [1, 10, 30]
dfpMorosidad.loc[~dfpMorosidad['ID'].isin(listaID)]
# Out:
#       ID  edad  meses  max_ant   ingreso  score  tipo_vivienda  zona  nivel
# 1      2    27    173       61   2450.00    205              2     1      5
# 2      3    37    185        4   1390.00    177              2     3      5
# 3      4    34    262       20   2200.00    216              2     1      2
# 4      5    40    150       17  10000.00    185              2     1      2
# 5      6    40    114        0    903.88    173              2     3      5
# ..   ...   ...    ...      ...       ...    ...            ...   ...    ...
# 295  296    23    144        3   1368.60    156              2     3      5
# 296  297    23    131        0   1382.03    156              2     1      5
# 297  298    31    130       12   2000.00    188              2     1      2
# 298  299    33    170       12   5600.00    219              4     1      2
# 299  300    24    152        8    900.00    164              2     1      2
#
# [297 rows x 9 columns]

# %% [markdown]
# **Ejemplo 2:
# Genere una consulta que liste los clientes cuyo 'tipo_vivienda' no sea 2 ni 4**

# %%
# Resolver Aquí
listaTipo_vivienda = [2, 4]
dfpMorosidad.loc[~dfpMorosidad['tipo_vivienda'].isin(listaTipo_vivienda)]
# Out:
#       ID  edad  meses  max_ant  ingreso  score  tipo_vivienda  zona  nivel
# 46    47    27    136        8   3500.0    200              1     3      2
# 49    50    27    185       12   4200.0    179              1     1      2
# 109  110    33    150        0   2100.0    182              1     4      2
# 127  128    34    122       53   7055.0    175              3     1      5
# 272  273    31    140       12   1400.0    178              3     2      5

# %% [markdown]
# __Combinación de filtros (AND / OR)__

# %%
dfpMorosidad.dtypes

# %%
# AND
dfpMorosidad.loc[ ( dfpMorosidad['zona'] == 3 ) | ( dfpMorosidad['nivel'] == 5 ) ]
# Ojo tener cuidad con los tipos de dato
# Out:
#       ID  edad  meses  max_ant  ingreso  score  tipo_vivienda  zona  nivel
# 0      1    28    122        9  1115.09    206              4     1      5
# 1      2    27    173       61  2450.00    205              2     1      5
# 2      3    37    185        4  1390.00    177              2     3      5
# 5      6    40    114        0   903.88    173              2     3      5
# 6      7    31    161        0  3800.00    192              2     1      5
# ..   ...   ...    ...      ...      ...    ...            ...   ...    ...
# 292  293    39    125        0   880.00    215              4     1      5
# 293  294    35    288        0  4100.00    192              2     3      1
# 294  295    30    145        8  1500.00    194              2     1      5
# 295  296    23    144        3  1368.60    156              2     3      5
# 296  297    23    131        0  1382.03    156              2     1      5
#
# [197 rows x 9 columns]

# %% [markdown]
# **Ejemplo 3:
# Genere una consulta que liste los clientes cuyo 'tipo_vivienda' sea 1 y su 'nivel' no sea 4**

# %%
# Resolver Aqui
dfpMorosidad.loc[ ( dfpMorosidad['tipo_vivienda'] == 1 ) & ( dfpMorosidad['nivel'] !=4 ) ]
# Out:
#       ID  edad  meses  max_ant  ingreso  score  tipo_vivienda  zona  nivel
# 46    47    27    136        8   3500.0    200              1     3      2
# 49    50    27    185       12   4200.0    179              1     1      2
# 109  110    33    150        0   2100.0    182              1     4      2

# %%
dfpMorosidad.loc[ ( dfpMorosidad['tipo_vivienda'] == 1 ) & ~( dfpMorosidad['nivel'] == 4 ) ]
# Out:
#       ID  edad  meses  max_ant  ingreso  score  tipo_vivienda  zona  nivel
# 46    47    27    136        8   3500.0    200              1     3      2
# 49    50    27    185       12   4200.0    179              1     1      2
# 109  110    33    150        0   2100.0    182              1     4      2

# %%
# Resolver la pregunta 5
Filtro = (dfDepositos['CUENTA'] == 'AHORRO')
listCol = ['ID', 'CUENTA', 'MONTO_SOLES']
dfDepositos.loc[Filtro, listCol]
# Out:
#           ID  CUENTA  MONTO_SOLES
# 1    ID12797  AHORRO      1211.89
# 3    ID12798  AHORRO       541.13
# 5    ID12799  AHORRO       298.15
# 7    ID12800  AHORRO        88.85
# 9    ID12801  AHORRO       319.55
# ..       ...     ...          ...
# 182  ID12895  AHORRO       250.00
# 184  ID12896  AHORRO       134.00
# 186  ID12897  AHORRO        50.00
# 188  ID12899  AHORRO       230.00
# 190  ID12900  AHORRO      1125.00
#
# [67 rows x 3 columns]

# %%
# Resolver la pregunta 6
Tvivienda = [2,4]
filtro_tipo_vivienda = (dfpMorosidad['tipo_vivienda'].isin(Tvivienda))
listCol = ['ID', 'edad', 'tipo_vivienda']
dfpMorosidad.loc[filtro_tipo_vivienda , listCol]
# Out:
#       ID  edad  tipo_vivienda
# 0      1    28              4
# 1      2    27              2
# 2      3    37              2
# 3      4    34              2
# 4      5    40              2
# ..   ...   ...            ...
# 295  296    23              2
# 296  297    23              2
# 297  298    31              2
# 298  299    33              4
# 299  300    24              2
#
# [295 rows x 3 columns]

# %%
filtro = ((dfpMorosidad['tipo_vivienda']==2) | (dfpMorosidad['tipo_vivienda']==4) )
listCol = ['ID', 'edad', 'tipo_vivienda']
dfpMorosidad.loc[filtro,listCol]
# Out:
#       ID  edad  tipo_vivienda
# 0      1    28              4
# 1      2    27              2
# 2      3    37              2
# 3      4    34              2
# 4      5    40              2
# ..   ...   ...            ...
# 295  296    23              2
# 296  297    23              2
# 297  298    31              2
# 298  299    33              4
# 299  300    24              2
#
# [295 rows x 3 columns]

# %%
# Resolver la pregunta 7
listaCol = ['ID','edad','ingreso']
filtro = ( (dfpMorosidad['edad']>35) & (dfpMorosidad['ingreso']<5000))
dfpMorosidad.loc[filtro, listaCol]
# Out:
#       ID  edad  ingreso
# 2      3    37  1390.00
# 5      6    40   903.88
# 8      9    40  3680.00
# 9     10    36  4000.00
# 10    11    50  1182.72
# ..   ...   ...      ...
# 284  285    37  4500.00
# 285  286    40  3084.00
# 289  290    41  1400.00
# 290  291    36  3050.00
# 292  293    39   880.00
#
# [83 rows x 3 columns]

# %%
filtro = ((dfpMorosidad['edad']>35) & (dfpMorosidad['ingreso']<5000))
listCol = ['ID', 'edad', 'ingreso']
dfpMorosidad.loc[filtro,listCol]
# Out:
#       ID  edad  ingreso
# 2      3    37  1390.00
# 5      6    40   903.88
# 8      9    40  3680.00
# 9     10    36  4000.00
# 10    11    50  1182.72
# ..   ...   ...      ...
# 284  285    37  4500.00
# 285  286    40  3084.00
# 289  290    41  1400.00
# 290  291    36  3050.00
# 292  293    39   880.00
#
# [83 rows x 3 columns]

# %%
# Resolver la pregunta 8
ingreso_maximo = dfpMorosidad['ingreso'].max()
print(ingreso_maximo)
filtro = ( dfpMorosidad['ingreso'] == ingreso_maximo )
dfpMorosidad.loc[filtro]
# Out:
# 30000.0
#     ID  edad  meses  max_ant  ingreso  score  tipo_vivienda  zona  nivel
# 7    8    49    210       44  30000.0    203              4     1      3
# 90  91    26    117        7  30000.0    206              2     1      2
# 93  94    31    132        6  30000.0    223              4     3      5

# %%
variable = 'score'
listCol = ['edad', 'meses', 'score']
ingreso_maximo = dfpMorosidad[variable].min()
print(ingreso_maximo)
filtro = ( dfpMorosidad[variable] == ingreso_maximo )
dfpMorosidad.loc[filtro, listCol]
# Out:
# 150
#      edad  meses  score
# 59     38    166    150
# 220    38    182    150

# %% [markdown]
# ### Group By

# %%
dfHipotecario.reset_index().agg({'index':'count'})
# Out:
# index    614
# dtype: int64

# %%
listDim = ['REGION', 'SEXO']
dictMetrica = {'INGRESOS':'max', 'EDAD':'mean'}
filtro = ( dfClientes['AUTO'] == 'NO ' )
dfRes = dfClientes.loc[filtro].groupby(listDim, as_index = False).agg(dictMetrica)
dfRes['EDAD'] = np.round(dfRes['EDAD'], 0)
dfRes
# Out:
#              REGION         SEXO  INGRESOS  EDAD
# 0  LIMA_CENTRO          FEMENINO     39387  53.0
# 1  LIMA_CENTRO       MASCULINO       60176  40.0
# 2         LIMA_ESTE     FEMENINO     58002  44.0
# 3         LIMA_ESTE  MASCULINO       54182  44.0
# 4  LIMA_NORTE           FEMENINO     41406  42.0
# 5  LIMA_NORTE        MASCULINO       61476  36.0
# 6        LIMA_SUR       FEMENINO     48758  39.0
# 7        LIMA_SUR    MASCULINO       51468  48.0

# %%
# Count
dfpMorosidad.groupby('tipo_vivienda').agg({'ingreso':'mean'})
# Out:
#                    ingreso
# tipo_vivienda
# 1              3266.666667
# 2              3018.948673
# 3              4227.500000
# 4              4028.474928

# %%
dfpMorosidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             300 non-null    int64
#  1   edad           300 non-null    int64
#  2   meses          300 non-null    int64
#  3   max_ant        300 non-null    int64
#  4   ingreso        300 non-null    float64
#  5   score          300 non-null    int64
#  6   tipo_vivienda  300 non-null    int64
#  7   zona           300 non-null    int64
#  8   nivel          300 non-null    int64
# dtypes: float64(1), int64(8)
# memory usage: 21.2 KB

# %%
# Count
dfpMorosidad.groupby('tipo_vivienda', as_index = False).agg({'ID':'count'})

# %%
dfpMorosidad.sort_values(['tipo_vivienda', 'ingreso'], ascending = False).groupby(['tipo_vivienda']).cumcount() + 1

# %%
# Sum
dfpMorosidad.groupby('tipo_vivienda', as_index = False).agg({'ingreso':'sum'})

# %%
# Avg
dfpMorosidad.groupby('tipo_vivienda', as_index = False).agg({'ingreso':'mean'})

# %%
# Mas de una agrupacion
dfpMorosidad.groupby(['tipo_vivienda', 'nivel'], as_index = False).agg({'ingreso':'mean'})

# %%
# Pregunta 9
dfDepositos.groupby('CUENTA').agg({'ID':'count','MONTO_SOLES':'sum'})
# Out:
#             ID  MONTO_SOLES
# CUENTA
# AHORRO      67     73993.38
# CORRIENTE  126    106030.50

# %%
dfDepositos
listDim=['CUENTA']
dictMetrica={'ID':'count','MONTO_SOLES':'sum'}
dfDepositos.groupby(listDim, as_index = False).agg(dictMetrica)
# Out:
#       CUENTA   ID  MONTO_SOLES
# 0     AHORRO   67     73993.38
# 1  CORRIENTE  126    106030.50

# %%
# Pregunta 10
listDim = ['SEXO', 'REGION']
dictMetrica = {'ID':'count', 'INGRESOS':'mean'}
dfRes = dfClientes.groupby(listDim, as_index = False).agg(dictMetrica)
dfRes
# Out:
#           SEXO            REGION  ID      INGRESOS
# 0     FEMENINO  LIMA_CENTRO       10  28547.900000
# 1     FEMENINO         LIMA_ESTE  44  27676.886364
# 2     FEMENINO  LIMA_NORTE        34  26814.558824
# 3     FEMENINO        LIMA_SUR    17  26192.176471
# 4  MASCULINO    LIMA_CENTRO       12  31951.416667
# 5  MASCULINO           LIMA_ESTE  40  27539.525000
# 6  MASCULINO    LIMA_NORTE        26  23428.000000
# 7  MASCULINO          LIMA_SUR    15  24803.200000

# %% [markdown]
# ### Case When

# %%
dfpMorosidad
# Out:
#       ID  edad  meses  max_ant   ingreso  score  tipo_vivienda  zona  nivel
# 0      1    28    122        9   1115.09    206              4     1      5
# 1      2    27    173       61   2450.00    205              2     1      5
# 2      3    37    185        4   1390.00    177              2     3      5
# 3      4    34    262       20   2200.00    216              2     1      2
# 4      5    40    150       17  10000.00    185              2     1      2
# ..   ...   ...    ...      ...       ...    ...            ...   ...    ...
# 295  296    23    144        3   1368.60    156              2     3      5
# 296  297    23    131        0   1382.03    156              2     1      5
# 297  298    31    130       12   2000.00    188              2     1      2
# 298  299    33    170       12   5600.00    219              4     1      2
# 299  300    24    152        8    900.00    164              2     1      2
#
# [300 rows x 9 columns]

# %%
# Revision
dfpMorosidad['rango_edad'] = np.where( dfpMorosidad['edad'] > 35, 'Adulto',
                                      np.where( dfpMorosidad['edad'] > 25, 'Joven', 'Adoslecente' ) )
dfpMorosidad
# Out:
#       ID  edad  meses  max_ant   ingreso  score  tipo_vivienda  zona  nivel  \
# 0      1    28    122        9   1115.09    206              4     1      5
# 1      2    27    173       61   2450.00    205              2     1      5
# 2      3    37    185        4   1390.00    177              2     3      5
# 3      4    34    262       20   2200.00    216              2     1      2
# 4      5    40    150       17  10000.00    185              2     1      2
# ..   ...   ...    ...      ...       ...    ...            ...   ...    ...
# 295  296    23    144        3   1368.60    156              2     3      5
# 296  297    23    131        0   1382.03    156              2     1      5
# 297  298    31    130       12   2000.00    188              2     1      2
# 298  299    33    170       12   5600.00    219              4     1      2
# 299  300    24    152        8    900.00    164              2     1      2
#
#       rango_edad
# 0          Joven
# 1          Joven
# ...

# %%
listCortes = [0, 25, 35, np.inf]
listLabels = ['Adoslecente', 'Joven', 'Adulto']
dfpMorosidad['rango_edad'] = pd.cut(dfpMorosidad['edad'], listCortes, labels = listLabels)
dfpMorosidad
# Out:
#       ID  edad  meses  max_ant   ingreso  score  tipo_vivienda  zona  nivel  \
# 0      1    28    122        9   1115.09    206              4     1      5
# 1      2    27    173       61   2450.00    205              2     1      5
# 2      3    37    185        4   1390.00    177              2     3      5
# 3      4    34    262       20   2200.00    216              2     1      2
# 4      5    40    150       17  10000.00    185              2     1      2
# ..   ...   ...    ...      ...       ...    ...            ...   ...    ...
# 295  296    23    144        3   1368.60    156              2     3      5
# 296  297    23    131        0   1382.03    156              2     1      5
# 297  298    31    130       12   2000.00    188              2     1      2
# 298  299    33    170       12   5600.00    219              4     1      2
# 299  300    24    152        8    900.00    164              2     1      2
#
#       rango_edad
# 0          Joven
# 1          Joven
# ...

# %%
dfpMorosidad.groupby('Tramo_Edad').agg({'ingreso':'mean'})

# %% [markdown]
# # Join - Merge

# %%
# Importar el archivo "Curso.csv"
curso = pd.read_csv('https://raw.githubusercontent.com/aldochavez/datasets/main/Curso.csv', sep = ';')
curso
# Out:
#    idCurso            nombre  costo  duracion  idInstructor
# 0        1               SQL    100         2           6.0
# 1        2            Python     80         5           3.0
# 2        3                 R     70         5           2.0
# 3        4      SPSS Modeler     50         4           1.0
# 4        5  Machine Learning    200         8           1.0
# 5        6          Big Data    150         6           5.0
# 6        7           Tableau     60         2           6.0
# 7        8             Linux     75         4           NaN

# %%
# Importar el archivo "Estudiantes.csv"
estudiantes = pd.read_csv("https://raw.githubusercontent.com/aldochavez/datasets/main/Estudiantes.csv", sep = '|')
estudiantes
# Out:
#     codEstudiante       nombre    apellido   telefono
# 0               1  Jean Pierre      Levano  987654321
# 1               2        Sandy    Carbajal  987654322
# 2               3     Josselin       Taipe  987654323
# 3               4        James  Surichaqui  987654324
# 4               5       Javier        Ruiz  987654325
# 5               6      Enrique     Basauri  987654326
# 6               7    Alexander    Broncano  987654327
# 7               8        Marco       Marin  987654328
# 8               9        Oscar      Urbano  987654329
# 9              10     Yankarlo     Vilchez  987654330
# 10             11    Giancarlo    Torrejon  987654331
# 11             12      Roberto     Alvarez  987654332
# 12             13        Bruno        Diaz  987654333

# %%
# Importar el archivo "Instructor.txt"
instructor = pd.read_csv("https://raw.githubusercontent.com/aldochavez/datasets/main/Instructor.txt", sep="\t")
instructor
# Out:
#    idInstructor  nombre   apellido   telefono
# 0             1   Andre     Chavez  123456789
# 1             2    Jose   Cardenas  123456788
# 2             3   Mario  Bocanegra  123456787
# 3             4  Charli    Gutarra  123456786
# 4             5    Aldo     Chavez  123456785
# 5             6   Frank     Rivera  123456784
# 6             7  Walter     Pinedo  123456783

# %%
# Importar el archivo "Matricula.txt"
matricula = pd.read_csv("https://raw.githubusercontent.com/aldochavez/datasets/main/Matricula.txt", sep="\t")
matricula
# Out:
#     idCurso  idEstudiante  periodo  nota  idInstructor
# 0         1             1   201801     7             6
# 1         1             2   201801     8             6
# 2         1             3   201801     9             6
# 3         1             4   201801     2             6
# 4         2             1   201801     5             3
# 5         2             2   201801    17             3
# 6         2             3   201801    11             3
# 7         2             4   201801    18             3
# 8         3             1   201801     3             2
# 9         3             2   201801     2             2
# 10        3             3   201801     7             2
# 11        3             4   201801    14             2
# 12        4             1   201801     0             1
# 13        4             2   201801     3             1
# 14        4             3   201801    10             1
# 15        4             4   201801    19             1
# ...

# %% [markdown]
# ## Uso de Joins

# %% [markdown]
# SELECT A.*, B.*
# FROM TABLA1 A
# [INNER|LEFT|RIGTH|FULL] JOIN TABLA2 ON A.CLAVE1 = B.CLAVE2

# %% [markdown]
# ## 4.1.- Inner Join
#
#     // Inner join implicito
#     Cuando las claves son iguales:
#     df1.merge(df2, on = "clave")
#     Cuando las claves no son iguales:
#     df1.join(df2, left_on = "clave1", rigth_on = "clave2")
#
#     // Inner join implicito
#     Cuando las claves son iguales:
#     df1.merge(df2, on = ["clave"], how = 'inner')
#     Cuando las claves no son iguales:
#     df1.join(df2, left_on = "clave1", rigth_on = "clave2", how = 'inner')

# %%
instructor
# Out:
#    idInstructor  nombre   apellido   telefono
# 0             1   Andre     Chavez  123456789
# 1             2    Jose   Cardenas  123456788
# 2             3   Mario  Bocanegra  123456787
# 3             4  Charli    Gutarra  123456786
# 4             5    Aldo     Chavez  123456785
# 5             6   Frank     Rivera  123456784
# 6             7  Walter     Pinedo  123456783

# %%
curso
# Out:
#    idCurso            nombre  costo  duracion  idInstructor
# 0        1               SQL    100         2           6.0
# 1        2            Python     80         5           3.0
# 2        3                 R     70         5           2.0
# 3        4      SPSS Modeler     50         4           1.0
# 4        5  Machine Learning    200         8           1.0
# 5        6          Big Data    150         6           5.0
# 6        7           Tableau     60         2           6.0
# 7        8             Linux     75         4           NaN

# %%
# SELECT A.*, B.*
# FROM CURSO A
# INNER JOIN INSTRUCTOR B
# ON A.idInstructor = B.idInstructor
# Forma 1
curso.merge(instructor, on=["idInstructor"])
# Out:
#    idCurso          nombre_x  costo  duracion  idInstructor nombre_y  \
# 0        1               SQL    100         2           6.0    Frank
# 1        7           Tableau     60         2           6.0    Frank
# 2        2            Python     80         5           3.0    Mario
# 3        3                 R     70         5           2.0     Jose
# 4        4      SPSS Modeler     50         4           1.0    Andre
# 5        5  Machine Learning    200         8           1.0    Andre
# 6        6          Big Data    150         6           5.0     Aldo
#
#     apellido   telefono
# 0     Rivera  123456784
# 1     Rivera  123456784
# 2  Bocanegra  123456787
# 3   Cardenas  123456788
# 4     Chavez  123456789
# 5     Chavez  123456789
# 6     Chavez  123456785

# %%
instructor

# %%
# SELECT A.nombre as NOMBRE_CURSO, B.NOMBRE as NOMBRE_PROFESOR
# FROM curso A
# inner join instructor B
# on A.idInstructor = B.idInstructor
listColCursos = ['idInstructor', 'nombre']
listColInstructor = ['idInstructor', 'nombre', 'apellido']
varID = "idInstructor"
dfUnion = curso[listColCursos].merge(instructor[listColInstructor], on=[varID])
dfUnion.drop(columns = 'idInstructor').rename(columns={'nombre_x':'NOMBRE_CURSO', 'nombre_y':'NOMBRE_PROFESOR'})
# Out:
#        NOMBRE_CURSO NOMBRE_PROFESOR   apellido
# 0               SQL           Frank     Rivera
# 1           Tableau           Frank     Rivera
# 2            Python           Mario  Bocanegra
# 3                 R            Jose   Cardenas
# 4      SPSS Modeler           Andre     Chavez
# 5  Machine Learning           Andre     Chavez
# 6          Big Data            Aldo     Chavez

# %% [markdown]
# ## 4.2.- Left Join
#
#     Cuando las claves son iguales:
#     df1.merge(df2, on=["clave"], how='left')
#     Cuando las claves no son iguales:
#     df1.merge(df2, left_on = "clave1", rigth_on = "clave2", how = "left")

# %%
# SELECT A.*, B.*
# FROM CURSO A
# LEFT JOIN INSTRUCTOR B
# ON A.idInstructor = B.idInstructor
# Forma 1
curso.merge(instructor, on=["idInstructor"], how = 'left')
# Out:
#    idCurso          nombre_x  costo  duracion  idInstructor nombre_y  \
# 0        1               SQL    100         2           6.0    Frank
# 1        2            Python     80         5           3.0    Mario
# 2        3                 R     70         5           2.0     Jose
# 3        4      SPSS Modeler     50         4           1.0    Andre
# 4        5  Machine Learning    200         8           1.0    Andre
# 5        6          Big Data    150         6           5.0     Aldo
# 6        7           Tableau     60         2           6.0    Frank
# 7        8             Linux     75         4           NaN      NaN
#
#     apellido     telefono
# 0     Rivera  123456784.0
# 1  Bocanegra  123456787.0
# 2   Cardenas  123456788.0
# 3     Chavez  123456789.0
# 4     Chavez  123456789.0
# 5     Chavez  123456785.0
# 6     Rivera  123456784.0
# 7        NaN          NaN

# %%
# Cual es la diferencia?
curso.merge(instructor, on=["idInstructor"], how = 'inner')
# Out:
#    idCurso          nombre_x  costo  duracion  idInstructor nombre_y  \
# 0        1               SQL    100         2           6.0    Frank
# 1        7           Tableau     60         2           6.0    Frank
# 2        2            Python     80         5           3.0    Mario
# 3        3                 R     70         5           2.0     Jose
# 4        4      SPSS Modeler     50         4           1.0    Andre
# 5        5  Machine Learning    200         8           1.0    Andre
# 6        6          Big Data    150         6           5.0     Aldo
#
#     apellido   telefono
# 0     Rivera  123456784
# 1     Rivera  123456784
# 2  Bocanegra  123456787
# 3   Cardenas  123456788
# 4     Chavez  123456789
# 5     Chavez  123456789
# 6     Chavez  123456785

# %% [markdown]
# ## 4.3.- Rigth Join
#
#     Cuando las claves son iguales:
#     df1.merge(df2, on=["clave"], how='right')
#     Cuando las claves no son iguales:
#     df1.merge(df2, left_on = "clave1", rigth_on = "clave2", how = "right")

# %%
# SELECT A.*, B.*
# FROM CURSO A
# LEFT JOIN INSTRUCTOR B
# ON A.idInstructor = B.idInstructor
# Forma 1
curso.merge(instructor, on=["idInstructor"], how = 'right')
# Out:
#    idCurso          nombre_x  costo  duracion  idInstructor nombre_y  \
# 0      4.0      SPSS Modeler   50.0       4.0           1.0    Andre
# 1      5.0  Machine Learning  200.0       8.0           1.0    Andre
# 2      3.0                 R   70.0       5.0           2.0     Jose
# 3      2.0            Python   80.0       5.0           3.0    Mario
# 4      NaN               NaN    NaN       NaN           4.0   Charli
# 5      6.0          Big Data  150.0       6.0           5.0     Aldo
# 6      1.0               SQL  100.0       2.0           6.0    Frank
# 7      7.0           Tableau   60.0       2.0           6.0    Frank
# 8      NaN               NaN    NaN       NaN           7.0   Walter
#
#     apellido   telefono
# 0     Chavez  123456789
# 1     Chavez  123456789
# 2   Cardenas  123456788
# 3  Bocanegra  123456787
# 4    Gutarra  123456786
# 5     Chavez  123456785
# 6     Rivera  123456784
# 7     Rivera  123456784
# 8     Pinedo  123456783

# %%
# Cual es la diferencia?
curso.merge(instructor, on=["idInstructor"], how = 'left')
# Out:
#    idCurso          nombre_x  costo  duracion  idInstructor nombre_y  \
# 0        1               SQL    100         2           6.0    Frank
# 1        2            Python     80         5           3.0    Mario
# 2        3                 R     70         5           2.0     Jose
# 3        4      SPSS Modeler     50         4           1.0    Andre
# 4        5  Machine Learning    200         8           1.0    Andre
# 5        6          Big Data    150         6           5.0     Aldo
# 6        7           Tableau     60         2           6.0    Frank
# 7        8             Linux     75         4           NaN      NaN
#
#     apellido     telefono
# 0     Rivera  123456784.0
# 1  Bocanegra  123456787.0
# 2   Cardenas  123456788.0
# 3     Chavez  123456789.0
# 4     Chavez  123456789.0
# 5     Chavez  123456785.0
# 6     Rivera  123456784.0
# 7        NaN          NaN

# %%
instructor.merge(curso, on=["idInstructor"], how = 'right')
# Out:
#    idInstructor nombre_x   apellido     telefono  idCurso          nombre_y  \
# 0           6.0    Frank     Rivera  123456784.0        1               SQL
# 1           3.0    Mario  Bocanegra  123456787.0        2            Python
# 2           2.0     Jose   Cardenas  123456788.0        3                 R
# 3           1.0    Andre     Chavez  123456789.0        4      SPSS Modeler
# 4           1.0    Andre     Chavez  123456789.0        5  Machine Learning
# 5           5.0     Aldo     Chavez  123456785.0        6          Big Data
# 6           6.0    Frank     Rivera  123456784.0        7           Tableau
# 7           NaN      NaN        NaN          NaN        8             Linux
#
#    costo  duracion
# 0    100         2
# 1     80         5
# 2     70         5
# 3     50         4
# 4    200         8
# 5    150         6
# 6     60         2
# 7     75         4

# %% [markdown]
# ## 4.4.- Full Join
#
#     Cuando las claves son iguales:
#     df1.merge(df2, on=["clave"], how='full_outer')
#     Cuando las claves no son iguales:
#     df1.merge(df2, left_on = "clave1", rigth_on = "clave2", how = "outer")

# %%
# SELECT A.*, B.*
# FROM CURSO A
# LEFT JOIN INSTRUCTOR B
# ON A.idInstructor = B.idInstructor
# Forma 1
curso.merge(instructor, on=["idInstructor"], how = 'outer')

# %%
# Forma 2
curso.rename(columns={'idInstructor':'codInstructor'}).merge(instructor, left_on = "codInstructor", right_on = "idInstructor", how = 'outer')

# %%
# Forma 2
dfAux = curso.merge(instructor.rename(columns={'idInstructor':'codInstructor'}), left_on = "idInstructor", right_on = "codInstructor", how = 'outer', indicator = True)
dfAux

# %%
dfAux.loc[dfAux['_merge'].isin(['left_only', 'right_only'])]

# %%
dfAux.loc[dfAux['_merge'] != 'both']

# %%
estudiantes.rename(columns = {'codEstudiante':'idEstudiante'}, inplace = True)

# %%
matricula

# %%
dfUni = matricula.merge(estudiantes, how = 'left', on = 'idEstudiante')\
  .merge(curso.drop(columns = 'idInstructor').rename(columns = {'nombre':'nombre_curso'}), how = 'left', on = 'idCurso')\
  .merge(instructor.rename(columns = {'nombre':'nombre_profe', 'apellido':'apellido_profe'}), how = 'left', on = 'idInstructor')

# %%
dfUni.groupby('nombre_profe', as_index = False).agg({'nota':'mean'}).sort_values('nota')

# %%
import glob
ruta = '/content/Carpeta/*.csv'
listaArchivos = [a for a in glob.glob(ruta)]
listaArchivos
df = pd.DataFrame()
for archivo in listaArchivos:
  print(archivo)
  dfAux = pd.read_csv(archivo)
  dfAux['archivo'] = archivo
  #display(dfAux)
  df = pd.concat([df, dfAux], ignore_index=True, axis = 1)
df

# %%
df

# %%
df['archivo'].value_counts()

# %%
dfUni

# %%
dfUni['row_num'] = dfUni.sort_values(['nombre_profe', 'nota'], ascending=[1, 0]).groupby(['nombre_profe']).cumcount() + 1

# %%
dfUni.sort_values(['nombre_profe', 'row_num']).loc[dfUni['row_num'] <= 5]#.to_excel('Base_Top.xlsx')
